# %%
using DataFrames, Plots, CSV

# %% [markdown]
# ### Read the data

# %%
df1  = DataFrame(CSV.File("./df1_bis.csv"))
min1 = findmin(df1[:,4],dims=1)
ind1 = findall(df1[:,4].==min1[1])
@show length(ind1)
df1[ind1,:]
# Out:
# length(ind1) = 29
# 29×12 DataFrame
#  Row │ dtP_fact  dtV_fact  θ_fact   iters    dtP        dtV          theta     ⋯
#      │ Float64   Float64   Float64  Float64  Float64    Float64      Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1.4       1.24     1.4     300.0  0.0169697  0.000860021  0.1905    ⋯
#    2 │     1.48      1.24     1.4     300.0  0.0179394  0.000860021  0.195583
#    3 │     1.48      1.24     1.48    300.0  0.0179394  0.000860021  0.200055
#    4 │     1.56      1.16     1.4     300.0  0.0189091  0.000860021  0.192931
#    5 │     1.56      1.24     1.4     300.0  0.0189091  0.000860021  0.200243  ⋯
#    6 │     1.56      1.24     1.48    300.0  0.0189091  0.000860021  0.205304
#    7 │     1.56      1.24     1.56    300.0  0.0189091  0.000860021  0.208674
#    8 │     1.56      1.32     1.4     300.0  0.0189091  0.000860021  0.190295
# ...

# %%
df2  = DataFrame(CSV.File("./df2_bis.csv"))
min2 = findmin(df2[:,4],dims=1)
ind2 = findall(df2[:,4].==min2[1])
df2[ind2,:]
# Out:
# 1×12 DataFrame
#  Row │ dtP_fact  dtV_fact  θ_fact   iters    dtP        dtV          theta     ⋯
#      │ Float64   Float64   Float64  Float64  Float64    Float64      Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │      1.8      1.48     0.92    500.0  0.0110769  0.000221672  0.176975  ⋯
#                                                                5 columns omitted

# %%
df4  = DataFrame(CSV.File("./df4_bis.csv"))
min4 = findmin(df4[:,4],dims=1)
ind4 = findall(df4[:,4].==min4[1])
@show length(ind4)
df4[ind4,:]
# Out:
# length(ind4) = 1
# 1×12 DataFrame
#  Row │ dtP_fact  dtV_fact  θ_fact   iters    dtP         dtV         theta     ⋯
#      │ Float64   Float64   Float64  Float64  Float64     Float64     Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1.56      1.64     0.68    950.0  0.00483721  5.62804e-5  0.32327   ⋯
#                                                                5 columns omitted

# %%
df8  = DataFrame(CSV.File("./df8_bis.csv"))
min8 = findmin(df8[:,4],dims=1)
ind8 = findall(df8[:,4].==min8[1])
@show length(ind8)
df8[ind8,:]
# Out:
# length(ind8) = 4
# 4×12 DataFrame
#  Row │ dtP_fact  dtV_fact  θ_fact   iters    dtP         dtV         theta     ⋯
#      │ Float64   Float64   Float64  Float64  Float64     Float64     Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     0.84      1.64     0.68   2200.0  0.00130739  1.41798e-5  0.342072  ⋯
#    2 │     1.08      1.56     0.76   2200.0  0.00168093  1.41798e-5  0.361061
#    3 │     1.08      1.64     0.76   2200.0  0.00168093  1.41798e-5  0.386246
#    4 │     1.64      1.72     0.6    2200.0  0.00255253  1.41798e-5  0.260899
#                                                                5 columns omitted

# %% [markdown]
# ### Combine all results

# %%
dtV   = [df1[ind1[1],6] df2[ind2[1],6] df4[ind4,6]  df8[ind8[1],6]]
dtP   = [df1[ind1[1],5] df2[ind2[1],5] df4[ind4,5]  df8[ind8[1],5]]
θ     = [df1[ind1[1],7] df2[ind2[1],7] df4[ind4,7]  df8[ind8[1],7]]
Lmax  = [df1[ind1[1],9] df2[ind2[1],9] df4[ind4,9]  df8[ind8[1],9]]
# dx    = [df1[1,end-1]   df2[1,end-1]   df4[1,end-1] df8[1,end-1]]
# iters = [df1[ind0[1],4] df2[ind2[1],4] df4[ind4,4]  df8[ind8[1],4]]
# Out:
# 1×4 Matrix{Float64}:
#  2323.2  9013.33  35500.8  1.40905e5

# %%
plot((dx[:].^2), 2.0./Lmax[:])
scatter!((dx[:].^2), (dtV[:]))

# %%
plot((dx[:].^(1/2)), Lmax[:])
scatter!((dx[:].^(1/2)), (dtP[:]))

# %%
i = 10
θ     = [df1[ind1[1],i] df2[ind2[1],i] df4[ind4,i]  df8[ind8[1],i]]
# Out:
# 1×4 Matrix{Float64}:
#  5.97882  4.498  8.54512  2.77618

# %%
dtV[1:end-1] ./ dtV[2:end]
# Out:
# 3-element Vector{Float64}:
#  3.8797061524334246
#  3.938698224852072
#  3.969052340604531
